# %%
# %run ./load_local.py -w

import importlib
from geolayer.api import vectorAPI

# %% [markdown]
# ### layers

# %%
# Shapefile
importlib.reload(vectorAPI)
res = vectorAPI.layers('/data/NUTS_RG_03M_2021_4326_0.shp')
res

# %%
# Geopackage
importlib.reload(vectorAPI)
res = vectorAPI.layers('/data/IsleofMan.gpkg')
res

# %%
# SQlite
importlib.reload(vectorAPI)
res = vectorAPI.layers('/data/BA_effis.sqlite')
res

# %% [markdown]
# ### layer: returns extent, geometry type, number of features, epsg, etc.

# %%
# Shapefile (layer can be omitted!)
importlib.reload(vectorAPI)
res = vectorAPI.layer('/data/NUTS_RG_03M_2021_4326_0.shp')
res

# %%
# Geopackage
importlib.reload(vectorAPI)
res = vectorAPI.layer('/data/IsleofMan.gpkg', layer_name='31311023')
res

# %%
# Geopackage
importlib.reload(vectorAPI)
res = vectorAPI.layer('/data/dbsm-v1-malta-merge.gpkg', layer_name='dbsm-v1-malta-merge')
res

# %%
# SQlite
importlib.reload(vectorAPI)
res = vectorAPI.layer('/data/BA_effis.sqlite', layer_name='2016')
res

# %% [markdown]
# ### fields: returns a dictionary with field names as key

# %%
# Shapefile (layer can be omitted!)
importlib.reload(vectorAPI)
res = vectorAPI.fields('/data/NUTS_RG_03M_2021_4326_0.shp')
res

# %%
# Shapefile
importlib.reload(vectorAPI)
res = vectorAPI.fields('/data/World_Fao_Zones.shp')
res

# %%
# Geopackage
importlib.reload(vectorAPI)
res = vectorAPI.fields('/data/IsleofMan.gpkg', layer_name='31311023')
res

# %%
# SQlite
importlib.reload(vectorAPI)
res = vectorAPI.fields('/data/BA_effis.sqlite', layer_name='2016')
res

# %% [markdown]
# ### field: returns info on a field

# %%
# Shapefile (layer can be omitted!)
importlib.reload(vectorAPI)
res = vectorAPI.field('/data/NUTS_RG_03M_2021_4326_0.shp', 'NUTS_ID')
res

# %%
# Geopackage
importlib.reload(vectorAPI)
res = vectorAPI.field('/data/IsleofMan.gpkg', layer_name='31311023', field_name='properties')
res

# %%
# SQlite
importlib.reload(vectorAPI)
res = vectorAPI.field('/data/BA_effis.sqlite', layer_name='2016', field_name='area_ha')
res

# %% [markdown]
# ### values: returns the list of all values of a field

# %%
# Shapefile (layer can be omitted!)
importlib.reload(vectorAPI)
res = vectorAPI.values('/data/NUTS_RG_03M_2021_4326_0.shp', 'CNTR_CODE')
res

# %%
# Geopackage
importlib.reload(vectorAPI)
res = vectorAPI.values('/data/IsleofMan.gpkg', layer_name='31311023', field_name='properties')
res

# %%
# SQlite
importlib.reload(vectorAPI)
res = vectorAPI.values('/data/BA_effis.sqlite', layer_name='2016', field_name='area_ha')
res

# %% [markdown]
# ### distinct: returns a dictionary with all the distinct values of a field and their number of occurrencies

# %%
# Shapefile (layer can be omitted!)
importlib.reload(vectorAPI)
res = vectorAPI.distinct('/data/NUTS_RG_03M_2021_4326_0.shp', 'CNTR_CODE')
res

# %%
# Geopackage
importlib.reload(vectorAPI)
res = vectorAPI.distinct('/data/IsleofMan.gpkg', layer_name='31311023', field_name='properties')
res

# %%
# SQlite
importlib.reload(vectorAPI)
res = vectorAPI.distinct('/data/BA_effis.sqlite', layer_name='2016', field_name='country')
res

# %% [markdown]
# ### stats: returns a dictionary with the statistics of a numeric field (min, max, mean, stddev)

# %%
# Shapefile (layer can be omitted!)
importlib.reload(vectorAPI)
res = vectorAPI.stats('/data/AirfldP.shp', 'USE')
res

# %%
# Geopackage
importlib.reload(vectorAPI)
res = vectorAPI.stats('/data/IsleofMan.gpkg', layer_name='31311023', field_name='properties')
res

# %%
# SQlite
importlib.reload(vectorAPI)
res = vectorAPI.stats('/data/BA_effis.sqlite', layer_name='2016', field_name='area_ha')
res

# %% [markdown]
# ### identify: search the nearest feature to a point in lat/lon coordinates using tolerance (to be set greater than 0 for polylines and points!)

# %%
# Shapefile (layer can be omitted!)
importlib.reload(vectorAPI)
res = vectorAPI.identify('/data/NUTS_RG_03M_2021_4326_0.shp', lon=12, lat=43, tolerance=0, geom=False)
res

# %%
# Shapefile points
importlib.reload(vectorAPI)
res = vectorAPI.identify('/data/AirfldP.shp', lon=12, lat=43, tolerance=0.5, geom=False)
res

# %%
# Geopackage
importlib.reload(vectorAPI)
res = vectorAPI.identify('/data/IsleofMan.gpkg', layer_name='31311023', lon=-4.6575, lat=54.0767, tolerance=0.1, geom=False)
res

# %%
# SQlite
importlib.reload(vectorAPI)
res = vectorAPI.identify('/data/BA_effis.sqlite', layer_name='2016', lon=-8.0, lat=41.0, tolerance=0.00001, geom=True)
res
