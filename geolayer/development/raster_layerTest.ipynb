# %%
# %run ./load_local.py -w

import importlib
from geolayer.layer import raster_layer

# %%
# %run ./load_local.py -w

import importlib
from geolayer.layer.raster_layer import RasterLayer

# %% [markdown]
# ### Single Band using a colorlist

# %%
importlib.reload(raster_layer)
import plotly.express as px
from vois.geo import Map

ly = raster_layer.RasterLayer.single('/data/CAMX_LAMMA_2019_NO2_IT_TUSCANY-MAP_FILE-20240731-ee2be3-1167.tiff', band=1) #, epsg=3035, nodata=0.0)

ly.colorlist(0.0, 10.0, px.colors.sequential.Viridis)

print('Identify: ', ly.identify(lon=10.0, lat=43.0))

#ly.print()
#print(ly.xml())
#print(ly.tileUrl(file_format='webp'))

m = Map.Map(zoom=8, center=[43.33316939281735, 11.282949043606514], basemapindex=0)
m.addLayer(ly)
m.onclick = ly.onclick
m

# %%
print(ly.xml())

# %%
importlib.reload(raster_layer)
import plotly.express as px
from vois.geo import Map

ly = raster_layer.RasterLayer.single('/data/Hansen_GFC-2019-v1.7_last_20N_060W.tif', band=1) #, epsg=3035, nodata=0.0)

ly.symbolizer(scaling="near")
ly.colorlist(0.0, 100.0, px.colors.sequential.Viridis)

print('Identify: ', ly.identify(lon=-59.57, lat=13.13))

#ly.print()
#print(ly.xml())
#print(ly.tileUrl(file_format='webp'))

m = Map.Map(zoom=11, center=[13.167079662405635, -59.44912140989895])
m.addLayer(ly)
m.onclick = ly.onclick
m

# %%
m.zoom

# %%
importlib.reload(raster_layer)
import plotly.express as px
from vois.geo import Map

ly = raster_layer.RasterLayer.single('/data/N36-W033.tif', band=1)

ly.symbolizer(scaling="near")
ly.colorlist(0.0, 200.0, px.colors.sequential.Viridis)

#print('Identify: ', ly.identify(lon=-31.10, lat=38.56))

#ly.print()
#print(ly.xml())
#print(ly.tileUrl(file_format='webp:quality=10'))

m = Map.Map(zoom=9, center=[38.53527591154413, -30.833261372068428], basemapindex=0)
m.addLayer(ly)
m.onclick = ly.onclick
m
# Out:
# Map(center=[38.53527591154413, -30.833261372068428], controls=(ZoomControl(options=['position', 'zoom_in_text'…

# %% [markdown]
# ### Single band using a colormap

# %%
importlib.reload(raster_layer)
from vois.geo import Map

colormap = {
      0: '#000000',
    211: '#a57000',
    212: '#896054',
    213: '#e2007c',
    214: '#aa007c',
    215: '#a05989',
    216: '#ffd300',
    217: '#00a8e2',
    218: '#d69ebc',
    219: '#d69ebc',
    221: '#dda50a',
    222: '#a800e2',
    223: '#00af49',
    230: '#00af49',
    231: '#ffff00',
    232: '#d1ff00',
    233: '#267000',
    240: '#f2a377',
    250: '#e8bfff',
    290: '#696969',
    300: '#93cc93',
    500: '#e8ffbf'
}


valuemap = {
    211: 'Common wheat',
    212: 'Durum wheat',
    213: 'Barley',
    214: 'Rye',
    215: 'Oats',
    216: 'Maize',
    217: 'Rice',
    218: 'Triticale',
    219: 'Other cereals',
    221: 'Potatoes',
    222: 'Sugar beet',
    223: 'Other root crops',
    230: 'Other non permanent industrial crops',
    231: 'Sunflower',
    232: 'Rape and turnip rape',
    233: 'Soya',
    240: 'Dry pulses',
    250: 'Fodder crops (cereals and leguminous)',
    290: 'Bare arable land',
    300: 'Woodland and Shrubland (incl. permanent crops)',
    500: 'Grasslands'
}

ly = raster_layer.RasterLayer.single("/data/eucropmap_masked_1366_1600.tif", band=1, identify_dict=valuemap, identify_integer=True)

ly.colormap(colormap)

print('Identify: ', ly.identify(lon=-3.64, lat=39.56))

#ly.print()
#print(ly.xml())
#print(ly.tileUrl(file_format='png'))

m = Map.Map(zoom=9, center=[39.51251701659638, -3.3949412207175382])
m.addLayer(ly)
m.onclick = ly.onclick
m

# %% [markdown]
# ### RGB display on bands from single file

# %%
importlib.reload(raster_layer)
from vois.geo import Map

ly = raster_layer.RasterLayer.rgb('/data/Hansen_GFC-2019-v1.7_last_20N_060W.tif',
                                  nodata=0.0,
                                  bandR=3,
                                  bandG=2,
                                  bandB=1,
                                  scalemin=[1.0, 0.0, 0.0],
                                  scalemax=[120.0, 100.0, 105.0],
                                  scaling='near')

#print('Identify: ',ly.identify(lon=-59.57, lat=13.13))

#ly.print()
#print(ly.xml())
#print(ly.tileUrl(file_format='webp:quality=30'))

m = Map.Map(height='900px', center=[13.186133837272225, -59.590873718261726], zoom=12)
m.addLayer(ly, opacity=0.99)
m.onclick = ly.onclick
m

# %%
importlib.reload(raster_layer)
from vois.geo import Map

#ly = raster_layer.RasterLayer.single('/data/Hansen_GFC-2019-v1.7_last_20N_060W.tif',band=1)
ly = raster_layer.RasterLayer.single('VRT:///data/Hansen_GFC-2019-v1.7_last_20N_060W.tif?bands=3,2,1',band=1)


ly.symbolizer(scaling="near")
ly.colorlist(0.0, 100.0, px.colors.sequential.Viridis)

m = Map.Map(height='900px', center=[13.186133837272225, -59.590873718261726], zoom=12)
m.addLayer(ly, opacity=0.99)
m.onclick = ly.onclick
m

# %% [markdown]
# ### RGB display on bands from multiple files

# %%
importlib.reload(raster_layer)
from vois.geo import Map

ly = raster_layer.RasterLayer.rgb_multiple(filepathR='/data/Hansen_GFC-2019-v1.7_last_20N_060W.tif',
                                           filepathG='/data/Hansen_GFC-2019-v1.7_last_20N_060W.tif',
                                           filepathB='/data/Hansen_GFC-2019-v1.7_last_20N_060W.tif',
                                           nodata=0.0,
                                           bandR=3,
                                           bandG=2,
                                           bandB=1,
                                           scalemin=[1.0, 0.0, 0.0],
                                           scalemax=[120.0, 100.0, 105.0],
                                           scaling='near')

#print('Identify: ',ly.identify(lon=-59.57, lat=13.13))

#ly.print()
#print(ly.xml())
#print(ly.tileUrl(file_format='png'))

m = Map.Map(height='900px', center=[13.186133837272225, -59.590873718261726], zoom=12)
m.addLayer(ly, opacity=0.99)
m.onclick = ly.onclick
m

# %% [markdown]
# ### SENTINEL-2 display

# %% [markdown]
# ##### Single band

# %%
importlib.reload(raster_layer)
import plotly.express as px
from vois.geo import Map

ly = raster_layer.RasterLayer.single('/data/S2A_MSIL2A_20230910T100601_N0509_R022_T33TUJ_20230910T161500.SAFE/GRANULE/L2A_T33TUJ_A042919_20230910T101420/IMG_DATA/R10m/T33TUJ_20230910T100601_B04_10m.jp2', band=1)

ly.colorlist(1000.0, 3000.0, px.colors.sequential.Viridis)

m = Map.Map(zoom=8, center=[43.33316939281735, 11.282949043606514], basemapindex=0)
m.addLayer(ly)
m.onclick = ly.onclick
m
# Out:
# Map(center=[43.33316939281735, 11.282949043606514], controls=(ZoomControl(options=['position', 'zoom_in_text',…

# %% [markdown]
# ##### RGB 3 bands composition from single band files

# %%
importlib.reload(raster_layer)
from vois.geo import Map

ly = raster_layer.RasterLayer.rgb_multiple(filepathR='/data/S2A_MSIL2A_20230910T100601_N0509_R022_T33TUJ_20230910T161500.SAFE/GRANULE/L2A_T33TUJ_A042919_20230910T101420/IMG_DATA/R10m/T33TUJ_20230910T100601_B04_10m.jp2',
                                           filepathG='/data/S2A_MSIL2A_20230910T100601_N0509_R022_T33TUJ_20230910T161500.SAFE/GRANULE/L2A_T33TUJ_A042919_20230910T101420/IMG_DATA/R10m/T33TUJ_20230910T100601_B03_10m.jp2',
                                           filepathB='/data/S2A_MSIL2A_20230910T100601_N0509_R022_T33TUJ_20230910T161500.SAFE/GRANULE/L2A_T33TUJ_A042919_20230910T101420/IMG_DATA/R10m/T33TUJ_20230910T100601_B02_10m.jp2',
                                           nodata=0.0,
                                           bandR=1,
                                           bandG=1,
                                           bandB=1,
                                           scalemin=[1000.0, 1000.0, 1000.0],
                                           scalemax=[3000.0, 3000.0, 3000.0],
                                           scaling='near')

m = Map.Map(zoom=8, center=[43.33316939281735, 11.282949043606514], basemapindex=0)
m.addLayer(ly, opacity=0.99)
m.onclick = ly.onclick
m

# %% [markdown]
# ##### RGB display of TCI image (True Colour Image)

# %%
importlib.reload(raster_layer)
from vois.geo import Map

ly = raster_layer.RasterLayer.rgb(filepath='/data/S2A_MSIL2A_20230910T100601_N0509_R022_T33TUJ_20230910T161500.SAFE/GRANULE/L2A_T33TUJ_A042919_20230910T101420/IMG_DATA/R10m/T33TUJ_20230910T100601_TCI_10m.jp2',
                                  nodata=0.0,
                                  bandR=1,
                                  bandG=2,
                                  bandB=3,
                                  scaling='bilinear')

m = Map.Map(zoom=8, center=[43.33316939281735, 11.282949043606514], basemapindex=0)
m.addLayer(ly, opacity=0.99)
m.onclick = ly.onclick
m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 importlib.reload(raster_layer)
#       2 from vois.geo import Map
#       4 ly = raster_layer.RasterLayer.rgb(filepath='/data/S2A_MSIL2A_20230910T100601_N0509_R022_T33TUJ_20230910T161500.SAFE/GRANULE/L2A_T33TUJ_A042919_20230910T101420/IMG_DATA/R10m/T33TUJ_20230910T100601_TCI_10m.jp2',
#       5                                   nodata=0.0,
#       6                                   bandR=1,
#       7                                   bandG=2,
#       8                                   bandB=3,
#       9                                   scaling='bilinear')
#
# NameError: name 'raster_layer' is not defined

# %% [markdown]
# ##### NDVI Index

# %%
importlib.reload(raster_layer)
from vois.geo import Map

ly = raster_layer.RasterLayer.index(filepath1='/data/S2A_MSIL2A_20230910T100601_N0509_R022_T33TUJ_20230910T161500.SAFE/GRANULE/L2A_T33TUJ_A042919_20230910T101420/IMG_DATA/R10m/T33TUJ_20230910T100601_B08_10m.jp2',
                                    filepath2='/data/S2A_MSIL2A_20230910T100601_N0509_R022_T33TUJ_20230910T161500.SAFE/GRANULE/L2A_T33TUJ_A042919_20230910T101420/IMG_DATA/R10m/T33TUJ_20230910T100601_B04_10m.jp2',
                                    band1=1,
                                    band2=1,
                                    scaling='near')

m = Map.Map(zoom=8, center=[43.33316939281735, 11.282949043606514], basemapindex=0)
m.addLayer(ly, opacity=0.99)
m.onclick = ly.onclick    # Doesn't work the identify!!!
m
# Out:
# Map(center=[43.33316939281735, 11.282949043606514], controls=(ZoomControl(options=['position', 'zoom_in_text',…
