# %%
# %run ./load_local.py -w

import importlib
from geolayer.layer import raster_layer

# %% [markdown]
# ### Single Band using a colorlist

# %%
importlib.reload(raster_layer)
import plotly.express as px
from vois.geo import Map

ly = raster_layer.RasterLayer.single('/data/CAMX_LAMMA_2019_NO2_IT_TUSCANY-MAP_FILE-20240731-ee2be3-1167.tiff', band=1) #, epsg=3035, nodata=0.0)

ly.colorlist(0.0, 10.0, px.colors.sequential.Viridis)

'''
m = Map.Map(zoom=14, basemapindex=1)
m.addLayer(ly)
m.onclick = ly.onclick
m
'''

print('Identify: ', ly.identify(lon=10.0, lat=43.0))

ly.print()
print(ly.xml())
print(ly.tileUrl(file_format='webp'))
# Out:
# Identify:  1.349527
# TILEGEO raster layer instance:
#    procid:         None
#    filepath:       /data/CAMX_LAMMA_2019_NO2_IT_TUSCANY-MAP_FILE-20240731-ee2be3-1167.tiff
#    band:           1
#    epsg:           None
#    proj:           +proj=utm +zone=32 +datum=WGS84 +units=m +no_defs
#    scaling:        near
#    opacity:        1.000000
#    default_mode:   linear
#    default_color:  transparent
#    epsilon:        0.0000001500000000
#    colorizer:
#        0.0000000000       #440154      linear
#        1.1111111111       #482878      linear
#        2.2222222222       #3e4989      linear
#        3.3333333333       #31688e      linear
#        4.4444444444       #26828e      linear
#        5.5555555556       #1f9e89      linear
#        6.6666666667       #35b779      linear
#        7.7777777778       #6ece58      linear
#        8.8888888889       #b5de2b      linear
#        10.0000000000      #fde725      linear
# <?xml version="1.0" encoding="utf-8"?>
# <!DOCTYPE Map[]>
# <Map srs="+proj=merc +a=6378137 +b=6378137 +lat_ts=0.0 +lon_0=0.0 +x_0=0.0 +y_0=0.0 +k=1.0 +units=m +nadgrids=@null +wktext +no_defs +over" background-color="#ffffff00" maximum-extent="-20037508.34,-20037508.34,20037508.34,20037508.34" buffer-size="50">
#     <Parameters>
#         <Parameter name="bounds">-180,-85.05112877980659,180,85.05112877980659</Parameter>
#         <Parameter name="center">0,0,2</Parameter>
#         <Parameter name="format">png</Parameter>
#         <Parameter name="minzoom">0</Parameter>
#         <Parameter name="maxzoom">22</Parameter>
#         <Parameter name="description">TILEGEO/GEOLAYER display system</Parameter>
#     </Parameters>
#
#     <Style name="b67a6579408baac31f1dbf4e0cb62e08_0" comp-op="src-over">
#         <Rule>
#             <RasterSymbolizer scaling="near" >
#                 <RasterColorizer default-mode="linear" default-color="transparent" epsilon="1.49999999999999993E-07">
#                     <stop color="#440154" value="0.0000000000" mode="linear" />
#                     <stop color="#482878" value="1.1111111111" mode="linear" />
#                     <stop color="#3e4989" value="2.2222222222" mode="linear" />
#                     <stop color="#31688e" value="3.3333333333" mode="linear" />
#                     <stop color="#26828e" value="4.4444444444" mode="linear" />
#                     <stop color="#1f9e89" value="5.5555555556" mode="linear" />
#                     <stop color="#35b779" value="6.6666666667" mode="linear" />
#                     <stop color="#6ece58" value="7.7777777778" mode="linear" />
#                     <stop color="#b5de2b" value="8.8888888889" mode="linear" />
#                     <stop color="#fde725" value="10.0000000000" mode="linear" />
#                 </RasterColorizer>
#             </RasterSymbolizer>
#         </Rule>
#     </Style>
#
#     <Layer name="b67a6579408baac31f1dbf4e0cb62e08" srs="+proj=utm +zone=32 +datum=WGS84 +units=m +no_defs">
#        <StyleName>b67a6579408baac31f1dbf4e0cb62e08_0</StyleName>
#        <Datasource>
#           <Parameter name="type">gdal</Parameter>
#           <Parameter name="file">/data/CAMX_LAMMA_2019_NO2_IT_TUSCANY-MAP_FILE-20240731-ee2be3-1167.tiff</Parameter>
#           <Parameter name="band">1</Parameter>
#        </Datasource>
#     </Layer>
# </Map>
# https://tilegeo.azurewebsites.net/dts/tile/108620f948e19499391d34facd9d00bc/{z}/{x}/{y}.webp

# %%
importlib.reload(raster_layer)
import plotly.express as px
from vois.geo import Map

ly = raster_layer.RasterLayer.single('/data/Hansen_GFC-2019-v1.7_last_20N_060W.tif', band=1) #, epsg=3035, nodata=0.0)

ly.symbolizer(scaling="near")
ly.colorlist(0.0, 100.0, px.colors.sequential.Viridis)

'''
m = Map.Map(zoom=14, basemapindex=1)
m.addLayer(ly)
m.onclick = ly.onclick
m
'''
print('Identify: ', ly.identify(lon=-59.57, lat=13.13))

#ly.print()
print(ly.xml())
print(ly.tileUrl(file_format='webp'))

# %%
importlib.reload(raster_layer)
import plotly.express as px
from vois.geo import Map

ly = raster_layer.RasterLayer.single('/data/N36-W033.tif', band=1)

ly.symbolizer(scaling="near")
ly.colorlist(0.0, 200.0, px.colors.sequential.Viridis)

'''
m = Map.Map(zoom=14, basemapindex=1)
m.addLayer(ly)
m.onclick = ly.onclick
m
'''

print('Identify: ', ly.identify(lon=-31.10, lat=38.56))

#ly.print()
print(ly.xml())
print(ly.tileUrl(file_format='webp:quality=10'))

# %% [markdown]
# ### Single band using a colormap

# %%
importlib.reload(raster_layer)
from vois.geo import Map

colormap = {
      0: '#000000',
    211: '#a57000',
    212: '#896054',
    213: '#e2007c',
    214: '#aa007c',
    215: '#a05989',
    216: '#ffd300',
    217: '#00a8e2',
    218: '#d69ebc',
    219: '#d69ebc',
    221: '#dda50a',
    222: '#a800e2',
    223: '#00af49',
    230: '#00af49',
    231: '#ffff00',
    232: '#d1ff00',
    233: '#267000',
    240: '#f2a377',
    250: '#e8bfff',
    290: '#696969',
    300: '#93cc93',
    500: '#e8ffbf'
}


valuemap = {
    211: 'Common wheat',
    212: 'Durum wheat',
    213: 'Barley',
    214: 'Rye',
    215: 'Oats',
    216: 'Maize',
    217: 'Rice',
    218: 'Triticale',
    219: 'Other cereals',
    221: 'Potatoes',
    222: 'Sugar beet',
    223: 'Other root crops',
    230: 'Other non permanent industrial crops',
    231: 'Sunflower',
    232: 'Rape and turnip rape',
    233: 'Soya',
    240: 'Dry pulses',
    250: 'Fodder crops (cereals and leguminous)',
    290: 'Bare arable land',
    300: 'Woodland and Shrubland (incl. permanent crops)',
    500: 'Grasslands'
}

ly = raster_layer.RasterLayer.single("/data/eucropmap_masked_1366_1600.tif", band=1, identify_dict=valuemap, identify_integer=True)

ly.colormap(colormap)

'''
m = Map.Map()
m.addLayer(ly)
m.onclick = ly.onclick
m
'''

print('Identify: ', ly.identify(lon=-3.64, lat=39.56))

#ly.print()
print(ly.xml())
print(ly.tileUrl(file_format='png'))
# Out:
# Identify:  213
# <?xml version="1.0" encoding="utf-8"?>
# <!DOCTYPE Map[]>
# <Map srs="+proj=merc +a=6378137 +b=6378137 +lat_ts=0.0 +lon_0=0.0 +x_0=0.0 +y_0=0.0 +k=1.0 +units=m +nadgrids=@null +wktext +no_defs +over" background-color="#ffffff00" maximum-extent="-20037508.34,-20037508.34,20037508.34,20037508.34" buffer-size="50">
#     <Parameters>
#         <Parameter name="bounds">-180,-85.05112877980659,180,85.05112877980659</Parameter>
#         <Parameter name="center">0,0,2</Parameter>
#         <Parameter name="format">png</Parameter>
#         <Parameter name="minzoom">0</Parameter>
#         <Parameter name="maxzoom">22</Parameter>
#         <Parameter name="description">TILEGEO/GEOLAYER display system</Parameter>
#     </Parameters>
#
#     <Style name="70b5e36927866d1f3a14cf6f1e408ac2_0" comp-op="src-over">
#         <Rule>
#             <RasterSymbolizer scaling="near" >
#                 <RasterColorizer default-mode="linear" default-color="transparent" epsilon="1.49999999999999993E-07">
#                     <stop color="#000000" value="0.0000000000" mode="linear" />
#                     <stop color="#a57000" value="211.0000000000" mode="linear" />
#                     <stop color="#896054" value="212.0000000000" mode="linear" />
#                     <stop color="#e2007c" value="213.0000000000" mode="linear" />
#                     <stop color="#aa007c" value="214.0000000000" mode="linear" />
#                     <stop color="#a05989" value="215.0000000000" mode="linear" />
#                     <stop color="#ffd300" value="216.0000000000" mode="linear" />
#                     <stop color="#00a8e2" value="217.0000000000" mode="linear" />
#                     <stop color="#d69ebc" value="218.0000000000" mode="linear" />
#                     <stop color="#d69ebc" value="219.0000000000" mode="linear" />
#                     <stop color="#dda50a" value="221.0000000000" mode="linear" />
#                     <stop color="#a800e2" value="222.0000000000" mode="linear" />
#                     <stop color="#00af49" value="223.0000000000" mode="linear" />
#                     <stop color="#00af49" value="230.0000000000" mode="linear" />
#                     <stop color="#ffff00" value="231.0000000000" mode="linear" />
#                     <stop color="#d1ff00" value="232.0000000000" mode="linear" />
#                     <stop color="#267000" value="233.0000000000" mode="linear" />
#                     <stop color="#f2a377" value="240.0000000000" mode="linear" />
#                     <stop color="#e8bfff" value="250.0000000000" mode="linear" />
#                     <stop color="#696969" value="290.0000000000" mode="linear" />
#                     <stop color="#93cc93" value="300.0000000000" mode="linear" />
#                     <stop color="#e8ffbf" value="500.0000000000" mode="linear" />
#                 </RasterColorizer>
#             </RasterSymbolizer>
#         </Rule>
#     </Style>
#
#     <Layer name="70b5e36927866d1f3a14cf6f1e408ac2" srs="+proj=laea +lat_0=52 +lon_0=10 +x_0=4321000 +y_0=3210000 +ellps=GRS80 +units=m +no_defs">
#        <StyleName>70b5e36927866d1f3a14cf6f1e408ac2_0</StyleName>
#        <Datasource>
#           <Parameter name="type">gdal</Parameter>
#           <Parameter name="file">/data/eucropmap_masked_1366_1600.tif</Parameter>
#           <Parameter name="band">1</Parameter>
#        </Datasource>
#     </Layer>
# </Map>
# https://tilegeo.azurewebsites.net/dts/tile/5bfb55743c2c3ac0d15f31ef858fb481/{z}/{x}/{y}.png

# %% [markdown]
# ### RGB display on bands from single file

# %%
importlib.reload(raster_layer)
from vois.geo import Map

ly = raster_layer.RasterLayer.rgb('/data/Hansen_GFC-2019-v1.7_last_20N_060W.tif',
                                  nodata=0.0,
                                  bandR=3,
                                  bandG=2,
                                  bandB=1,
                                  scalemin=[1.0, 0.0, 0.0],
                                  scalemax=[120.0, 100.0, 105.0],
                                  scaling='near')

'''
m = Map.Map(height='900px')
m.addLayer(ly, opacity=0.99)
m.onclick = ly.onclick
m
'''

print('Identify: ',ly.identify(lon=-59.57, lat=13.13))

ly.print()
print(ly.xml())
print(ly.tileUrl(file_format='webp:quality=30'))
# Out:
# Identify:  96,76,70
# TILEGEO raster layer instance:
#    procid:         None
#    filepath:       vrt:<VRTDataset rasterXSize="40000" rasterYSize="40000">
#   <GeoTransform>-60.0, 0.00025, 0.0, 20.0, 0.0, -0.00025</GeoTransform>
#   <VRTRasterBand dataType="Byte" band="1">
#     <ColorInterp>Red</ColorInterp>
#     <NoDataValue>0</NoDataValue>
#     <ComplexSource>
#       <SourceFilename relativeToVRT="0">/data/Hansen_GFC-2019-v1.7_last_20N_060W.tif</SourceFilename>
#       <SourceBand>3</SourceBand>
#     <NoDataValue>0</NoDataValue>
#       <SourceProperties RasterXSize="40000" RasterYSize="40000" DataType="Byte" />
#       <SrcRect xOff="0" yOff="0" xSize="40000" ySize="40000" />
#       <DstRect xOff="0" yOff="0" xSize="40000" ySize="40000" />
#       <ScaleRatio>2.1428571428571427937</ScaleRatio>
#       <ScaleOffset>-2.1428571428571427937</ScaleOffset>
#     </ComplexSource>
#   </VRTRasterBand>
#   <VRTRasterBand dataType="Byte" band="2">
#     <ColorInterp>Green</ColorInterp>
#     <NoDataValue>0</NoDataValue>
#     <ComplexSource>
#       <SourceFilename relativeToVRT="0">/data/Hansen_GFC-2019-v1.7_last_20N_060W.tif</SourceFilename>
#       <SourceBand>2</SourceBand>
#     <NoDataValue>0</NoDataValue>
#       <SourceProperties RasterXSize="40000" RasterYSize="40000" DataType="Byte" />
#       <SrcRect xOff="0" yOff="0" xSize="40000" ySize="40000" />
#       <DstRect xOff="0" yOff="0" xSize="40000" ySize="40000" />
#       <ScaleRatio>2.5499999999999998224</ScaleRatio>
#       <ScaleOffset>-0</ScaleOffset>
#     </ComplexSource>
#   </VRTRasterBand>
#   <VRTRasterBand dataType="Byte" band="3">
#     <ColorInterp>Blue</ColorInterp>
#     <NoDataValue>0</NoDataValue>
#     <ComplexSource>
#       <SourceFilename relativeToVRT="0">/data/Hansen_GFC-2019-v1.7_last_20N_060W.tif</SourceFilename>
#       <SourceBand>1</SourceBand>
#     <NoDataValue>0</NoDataValue>
#       <SourceProperties RasterXSize="40000" RasterYSize="40000" DataType="Byte" />
#       <SrcRect xOff="0" yOff="0" xSize="40000" ySize="40000" />
#       <DstRect xOff="0" yOff="0" xSize="40000" ySize="40000" />
#       <ScaleRatio>2.4285714285714283811</ScaleRatio>
#       <ScaleOffset>-0</ScaleOffset>
#     </ComplexSource>
#   </VRTRasterBand>
# </VRTDataset>
#
#    band:           0
#    epsg:           None
#    proj:           +proj=longlat +datum=WGS84 +no_defs
#    scaling:        near
#    opacity:        1.000000
#    default_mode:   linear
#    default_color:  transparent
#    epsilon:        0.0000001500000000
#    colorizer:      no
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 23
#      20 print('Identify: ',ly.identify(lon=-59.57, lat=13.13))
#      22 ly.print()
# ---> 23 print(ly.xml())
#      24 print(ly.tileUrl(file_format='webp:quality=30'))
#
# File /mnt/batch/tasks/shared/LS_root/mounts/clusters/compute-for-voila/code/geolayer/geolayer/layer/raster_layer.py:647, in RasterLayer.xml(self, compositing)
#     643 prefix = templates.MAP_PREFIX
#     645 styles = self.xml_styles(compositing=compositing)
# --> 647 layer = self.xml_layer()
#     649 end = templates.MAP_END
#     651 return prefix + '\n' + styles + '\n' + layer + '\n' + end
#
# File /mnt/batch/tasks/shared/LS_root/mounts/clusters/compute-for-voila/code/geolayer/geolayer/layer/raster_layer.py:700, in RasterLayer.xml_layer(self)
#     698 if self.filepath[:4] == "vrt:":
#     699     vrt_string = self.filepath[4:]
# --> 700     res = vrtAPI.vrtStore(vrt_string)
#     701     if 'file_path' in res:
#     702         filepath = res['file_path']
#
# File /mnt/batch/tasks/shared/LS_root/mounts/clusters/compute-for-voila/code/geolayer/geolayer/api/vrtAPI.py:60, in vrtStore(vrt_string)
#      58         res = json.loads(req.text)
#      59 else:
# ---> 60     raise InvalidAnswerException(url=url)
#      62 return res
#
# NameError: name 'url' is not defined

# %% [markdown]
# ### RGB display on bands from multiple files

# %%
importlib.reload(raster_layer)
from vois.geo import Map

ly = raster_layer.RasterLayer.rgb_multiple(filepathR='/data/Hansen_GFC-2019-v1.7_last_20N_060W.tif',
                                           filepathG='/data/Hansen_GFC-2019-v1.7_last_20N_060W.tif',
                                           filepathB='/data/Hansen_GFC-2019-v1.7_last_20N_060W.tif',
                                           nodata=0.0,
                                           bandR=3,
                                           bandG=2,
                                           bandB=1,
                                           scalemin=[1.0, 0.0, 0.0],
                                           scalemax=[120.0, 100.0, 105.0],
                                           scaling='near')

'''
m = Map.Map(height='900px')
m.addLayer(ly, opacity=0.99)
m.onclick = ly.onclick
m
'''

print('Identify: ',ly.identify(lon=-59.57, lat=13.13))

ly.print()
#print(ly.xml())
print(ly.tileUrl(file_format='png'))
# Out:
# Identify:  96,76,70
# TILEGEO raster layer instance:
#    procid:         None
#    filepath:       vrt:<VRTDataset rasterXSize="40000" rasterYSize="40000">
#   <GeoTransform>-60.0, 0.00025, 0.0, 20.0, 0.0, -0.00025</GeoTransform>
#   <VRTRasterBand dataType="Byte" band="1">
#     <ColorInterp>Red</ColorInterp>
#     <NoDataValue>0</NoDataValue>
#     <ComplexSource>
#       <SourceFilename relativeToVRT="0">/data/Hansen_GFC-2019-v1.7_last_20N_060W.tif</SourceFilename>
#       <SourceBand>3</SourceBand>
#     <NoDataValue>0</NoDataValue>
#       <SourceProperties RasterXSize="40000" RasterYSize="40000" DataType="Byte" />
#       <SrcRect xOff="0" yOff="0" xSize="40000" ySize="40000" />
#       <DstRect xOff="0" yOff="0" xSize="40000" ySize="40000" />
#       <ScaleRatio>2.1428571428571427937</ScaleRatio>
#       <ScaleOffset>-2.1428571428571427937</ScaleOffset>
#     </ComplexSource>
#   </VRTRasterBand>
#   <VRTRasterBand dataType="Byte" band="2">
#     <ColorInterp>Green</ColorInterp>
#     <NoDataValue>0</NoDataValue>
#     <ComplexSource>
#       <SourceFilename relativeToVRT="0">/data/Hansen_GFC-2019-v1.7_last_20N_060W.tif</SourceFilename>
#       <SourceBand>2</SourceBand>
#     <NoDataValue>0</NoDataValue>
#       <SourceProperties RasterXSize="40000" RasterYSize="40000" DataType="Byte" />
#       <SrcRect xOff="0" yOff="0" xSize="40000" ySize="40000" />
#       <DstRect xOff="0" yOff="0" xSize="40000" ySize="40000" />
#       <ScaleRatio>2.5499999999999998224</ScaleRatio>
#       <ScaleOffset>-0</ScaleOffset>
#     </ComplexSource>
#   </VRTRasterBand>
#   <VRTRasterBand dataType="Byte" band="3">
#     <ColorInterp>Blue</ColorInterp>
#     <NoDataValue>0</NoDataValue>
#     <ComplexSource>
#       <SourceFilename relativeToVRT="0">/data/Hansen_GFC-2019-v1.7_last_20N_060W.tif</SourceFilename>
#       <SourceBand>1</SourceBand>
#     <NoDataValue>0</NoDataValue>
#       <SourceProperties RasterXSize="40000" RasterYSize="40000" DataType="Byte" />
#       <SrcRect xOff="0" yOff="0" xSize="40000" ySize="40000" />
#       <DstRect xOff="0" yOff="0" xSize="40000" ySize="40000" />
#       <ScaleRatio>2.4285714285714283811</ScaleRatio>
#       <ScaleOffset>-0</ScaleOffset>
#     </ComplexSource>
#   </VRTRasterBand>
# </VRTDataset>
#
#    band:           0
#    epsg:           None
#    proj:           +proj=longlat +datum=WGS84 +no_defs
#    scaling:        near
#    opacity:        1.000000
#    default_mode:   linear
#    default_color:  transparent
#    epsilon:        0.0000001500000000
#    colorizer:      no
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 26
#      24 ly.print()
#      25 #print(ly.xml())
# ---> 26 print(ly.tileUrl(file_format='png'))
#
# File /mnt/batch/tasks/shared/LS_root/mounts/clusters/compute-for-voila/code/geolayer/geolayer/layer/raster_layer.py:622, in RasterLayer.tileUrl(self, file_format)
#     621 def tileUrl(self, file_format='png'):
# --> 622     procid = self.toLayer()
#     623     if not procid is None:
#     624         return '%s%s/{z}/{x}/{y}.%s'%(settings.TILE_ENDPOINT, procid, file_format)
#
# File /mnt/batch/tasks/shared/LS_root/mounts/clusters/compute-for-voila/code/geolayer/geolayer/layer/raster_layer.py:629, in RasterLayer.toLayer(self)
#     628 def toLayer(self):
# --> 629     xml = self.xml()
#     630     self.procid = redisAPI.redisStore(xml)
#     631     return self.procid
#
# File /mnt/batch/tasks/shared/LS_root/mounts/clusters/compute-for-voila/code/geolayer/geolayer/layer/raster_layer.py:647, in RasterLayer.xml(self, compositing)
#     643 prefix = templates.MAP_PREFIX
#     645 styles = self.xml_styles(compositing=compositing)
# --> 647 layer = self.xml_layer()
#     649 end = templates.MAP_END
#     651 return prefix + '\n' + styles + '\n' + layer + '\n' + end
#
# File /mnt/batch/tasks/shared/LS_root/mounts/clusters/compute-for-voila/code/geolayer/geolayer/layer/raster_layer.py:700, in RasterLayer.xml_layer(self)
#     698 if self.filepath[:4] == "vrt:":
#     699     vrt_string = self.filepath[4:]
# --> 700     res = vrtAPI.vrtStore(vrt_string)
#     701     if 'file_path' in res:
#     702         filepath = res['file_path']
#
# File /mnt/batch/tasks/shared/LS_root/mounts/clusters/compute-for-voila/code/geolayer/geolayer/api/vrtAPI.py:60, in vrtStore(vrt_string)
#      58         res = json.loads(req.text)
#      59 else:
# ---> 60     raise InvalidAnswerException(url=url)
#      62 return res
#
# NameError: name 'url' is not defined

# %% [markdown]
# ### SENTINEL-2 display (also with STAC integration)

# %% [markdown]
# ##### Read the STAC info on a Sentinel-2 product

# %%
import requests
import json
url = 'http://stac-api.cidsn.jrc.it:20008/services/stac-api/collections/EO.Copernicus.S2.L2A/items/S2A_MSIL2A_20230910T100601_N0509_R022_T32TQP_20230910T161500'
#url = 'http://stac-api.cidsn.jrc.it:20008/services/stac-api/collections/EO.Copernicus.S2.L2A/items/S2A_MSIL1C_20240901T100031_N0511_R122_T33TUJ_20240901T134329'
response = requests.get(url)
stacitem = json.loads(response.text)
#stacitem

# %% [markdown]
# ##### Single band

# %%
# %run ./development/load_local.py -w
from geolayer import rasterlayer
from vois.geo import Map
import plotly.express as px

#ly = rasterlayer.sentinel2single(stacitem, scalemin=800, scalemax=2800)
ly = rasterlayer.sentinel2single('S2A_MSIL2A_20230910T100601_N0509_R022_T32TQP_20230910T161500', 'B04', scaling='near', scalemin=800, scalemax=2800, colorlist=px.colors.sequential.Viridis)

m = Map.Map(center=[43.696, 12.1179], zoom=9)
m.addLayer(ly)
m.onclick = ly.onclick
m

# %% [markdown]
# ##### RGB 3 bands composition

# %%
# %run ./development/load_local.py -w
from geolayer import rasterlayer
from vois.geo import Map

#ly = rasterlayer.sentinel2rgb(stacitem, bandR='B08', bandG='B04', bandB='B03', scaling='near', scalemin=[1000, 600, 600], scalemax=[5000, 3000, 2800])
ly = rasterlayer.sentinel2rgb('S2A_MSIL2A_20230910T100601_N0509_R022_T32TQP_20230910T161500')

m = Map.Map(center=[43.696, 12.1179], zoom=9)
m.addLayer(ly)
m.onclick = ly.onclick
m

# %% [markdown]
# ##### Index

# %%
# %run ./development/load_local.py -w
from geolayer import rasterlayer
from vois.geo import Map

ly = rasterlayer.sentinel2index(stacitem, band1='B08', band2='B04', scaling='near', scalemin=0.0, scalemax=0.6)
#ly = rasterlayer.sentinel2index(stacitem, band1='B08', band2='B04', scaling='near')

m = Map.Map(center=[43.696, 12.1179], zoom=9)
m.addLayer(ly)
m.onclick = ly.onclick
m

# %% [markdown]
# ### Tests with new datasets

# %%
# %run ./development/load_local.py -w
from geolayer import rasterlayer
from vois.geo import Map

ly = rasterlayer.sentinel2index('S2A_MSIL2A_20240911T100021_N0511_R122_T32TQN_20240911T143249')

m = Map.Map(center=[42.796, 12.1179], zoom=9)
m.addLayer(ly)
m.onclick = ly.onclick
m

# %%
# %run ./development/load_local.py -w
from geolayer import rasterlayer
from vois.geo import Map

ly = rasterlayer.rgb('/eos/jeodpp/data/restricted/Orthoimagery/EUROPE/AIRBUS/PleiadesNeo/VHR2023_Orthorectified/Ortho_IT021.tif', nodata=0, scalemin=0, scalemax=2000, scaling='bilinear')

m = Map.Map(height='900px', center=[43.72682433969664, 13.062806083648832], zoom=13)
m.addLayer(ly)
m.onclick = ly.onclick
m

# %%
# %run ./development/load_local.py -w
from geolayer import rasterlayer
info = rasterlayer.info('/eos/jeodpp/data/base/Energy/EUROPE/ESA/Biomass_cci/VER3-0/Data/VRT/2018/2018_ESACCI_BIOMASS-L4-AGB.vrt')
display(info)

# %%
# %run ./development/load_local.py -w
from geolayer import rasterlayer
from vois.geo import Map
import plotly.express as px

ly = rasterlayer.single('/eos/jeodpp/data/base/Energy/EUROPE/ESA/Biomass_cci/VER3-0/Data/VRT/2018/2018_ESACCI_BIOMASS-L4-AGB.vrt', band=1, nodata=-1)
ly.symbolizer(scaling="bilinear")
ly.colorlist( 0.0, 120.0, px.colors.sequential.Viridis)

m = Map.Map(center=[50.5,5], zoom=8)
m.addLayer(ly)
m.onclick = ly.onclick
m

# %%
# %run ./development/load_local.py -w
from geolayer import rasterlayer
info = rasterlayer.info('/eos/jeodpp/data/base/Landcover/GLOBAL/FROM-GLC/2017/VER0-1/Data/VRT/fromglc10v01.vrt')
info

# %%
# %run ./development/load_local.py -w
from geolayer import rasterlayer
from vois.geo import Map
import plotly.express as px

ly = rasterlayer.single('/eos/jeodpp/data/base/Landcover/GLOBAL/FROM-GLC/2017/VER0-1/Data/VRT/fromglc10v01.vrt', band=1, nodata=0)
ly.symbolizer(scaling="bilinear")
ly.colorlist( 1.0, 100.0, px.colors.sequential.Viridis)

m = Map.Map(center=[50.5,5], zoom=8)
m.addLayer(ly)
m.onclick = ly.onclick
m
