# %%
# %run ./load_local.py -w

import importlib
from geolayer.api import redisAPI

# %% [markdown]
# ### redisStore

# %%
importlib.reload(redisAPI)
code = redisAPI.redisStore('abcdefghijklm', expire=200)
code
# Out:
# '22aebdd14e72f6b379476a146347d546'

# %% [markdown]
# ### redisGet

# %%
importlib.reload(redisAPI)
res = redisAPI.redisGet('22aebdd14e72f6b379476a146347d546')
res
# Out:
# 'abcdefghijklm'

# %% [markdown]
# ### redisDelete

# %%
importlib.reload(redisAPI)
res = redisAPI.redisDelete('22aebdd14e72f6b379476a146347d546')
res
# Out:
# True
