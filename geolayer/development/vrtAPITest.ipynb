# %%
# %run ./load_local.py -w

import importlib
from geolayer.api import vrtAPI

# %% [markdown]
# ### vrtStore

# %%
importlib.reload(vrtAPI)

vrt = '''<VRTDataset rasterXSize="40000" rasterYSize="40000">
  <GeoTransform>-60.0, 0.00025, 0.0, 20.0, 0.0, -0.00025</GeoTransform>
  <VRTRasterBand dataType="Byte" band="1">
    <ColorInterp>Red</ColorInterp>
    <NoDataValue>0</NoDataValue>
    <ComplexSource>
      <SourceFilename relativeToVRT="0">/data/Hansen_GFC-2019-v1.7_last_20N_060W.tif</SourceFilename>
      <SourceBand>3</SourceBand>
    <NoDataValue>0</NoDataValue>
      <SourceProperties RasterXSize="40000" RasterYSize="40000" DataType="Byte" />
      <SrcRect xOff="0" yOff="0" xSize="40000" ySize="40000" />
      <DstRect xOff="0" yOff="0" xSize="40000" ySize="40000" />
      <ScaleRatio>2.1428571428571427937</ScaleRatio>
      <ScaleOffset>-2.1428571428571427937</ScaleOffset>
    </ComplexSource>
  </VRTRasterBand>  <VRTRasterBand dataType="Byte" band="2">
    <ColorInterp>Green</ColorInterp>
    <NoDataValue>0</NoDataValue>
    <ComplexSource>
      <SourceFilename relativeToVRT="0">/data/Hansen_GFC-2019-v1.7_last_20N_060W.tif</SourceFilename>
      <SourceBand>2</SourceBand>
    <NoDataValue>0</NoDataValue>
      <SourceProperties RasterXSize="40000" RasterYSize="40000" DataType="Byte" />
      <SrcRect xOff="0" yOff="0" xSize="40000" ySize="40000" />
      <DstRect xOff="0" yOff="0" xSize="40000" ySize="40000" />
      <ScaleRatio>2.5499999999999998224</ScaleRatio>
      <ScaleOffset>-0</ScaleOffset>
    </ComplexSource>
  </VRTRasterBand>  <VRTRasterBand dataType="Byte" band="3">
    <ColorInterp>Blue</ColorInterp>
    <NoDataValue>0</NoDataValue>
    <ComplexSource>
      <SourceFilename relativeToVRT="0">/data/Hansen_GFC-2019-v1.7_last_20N_060W.tif</SourceFilename>
      <SourceBand>1</SourceBand>
    <NoDataValue>0</NoDataValue>
      <SourceProperties RasterXSize="40000" RasterYSize="40000" DataType="Byte" />
      <SrcRect xOff="0" yOff="0" xSize="40000" ySize="40000" />
      <DstRect xOff="0" yOff="0" xSize="40000" ySize="40000" />
      <ScaleRatio>2.4285714285714283811</ScaleRatio>
      <ScaleOffset>-0</ScaleOffset>
    </ComplexSource>
  </VRTRasterBand>
</VRTDataset>'''

res = vrtAPI.vrtStore(vrt)
res
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 47
#       1 importlib.reload(vrtAPI)
#       3 vrt = '''<VRTDataset rasterXSize="40000" rasterYSize="40000">
#       4   <GeoTransform>-60.0, 0.00025, 0.0, 20.0, 0.0, -0.00025</GeoTransform>
#       5   <VRTRasterBand dataType="Byte" band="1">
#    (...)
#      44   </VRTRasterBand>
#      45 </VRTDataset>'''
# ---> 47 res = vrtAPI.vrtStore(vrt)
#      48 res
#
# File /mnt/batch/tasks/shared/LS_root/mounts/clusters/compute-for-voila/code/geolayer/geolayer/api/vrtAPI.py:60, in vrtStore(vrt_string)
#      58         res = json.loads(req.text)
#      59 else:
# ---> 60     raise InvalidAnswerException(url=url)
#      62 return res
#
# NameError: name 'url' is not defined

# %% [markdown]
# ### vrtGet

# %%
importlib.reload(vrtAPI)
res = vrtAPI.vrtGet('24c3565bdb632990f2f25d3cb7b3afd1')
res
# Out:
# ---------------------------------------------------------------------------
# InvalidAnswerException                    Traceback (most recent call last)
# Cell In[6], line 2
#       1 importlib.reload(vrtAPI)
# ----> 2 res = vrtAPI.vrtGet('24c3565bdb632990f2f25d3cb7b3afd1')
#       3 res
#
# File /mnt/batch/tasks/shared/LS_root/mounts/clusters/compute-for-voila/code/geolayer/geolayer/api/vrtAPI.py:78, in vrtGet(code)
#      76         res = json.loads(req.text)
#      77 else:
# ---> 78     raise InvalidAnswerException(url=url)
#      80 return res
#
# InvalidAnswerException: tilegeo failed to correctly execute the command: http://141.227.140.197/dts/vrt/24c3565bdb632990f2f25d3cb7b3afd1
