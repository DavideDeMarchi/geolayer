# %%
# %run ./load_local.py -w

import importlib
from geolayer.api import rasterAPI

# %% [markdown]
# ### rasterInfo

# %%
importlib.reload(rasterAPI)
info = rasterAPI.rasterInfo('/data/CAMX_LAMMA_2019_NO2_IT_TUSCANY-MAP_FILE-20240731-ee2be3-1167.tiff', request_stats=True)
info
# Out:
# {'proj4': '+proj=utm +zone=32 +datum=WGS84 +units=m +no_defs',
#  'x_ul': 554000.0,
#  'x_res': 2000.0,
#  'x_skew': 0.0,
#  'y_ul': 4925000.0,
#  'y_skew': 0.0,
#  'y_res': -2000.0,
#  'geotransform': '554000.0, 2000.0, 0.0, 4925000.0, 0.0, -2000.0',
#  'count': 1,
#  'x_size': 110,
#  'y_size': 124,
#  'bands': {'1': {'x_size': 110,
#    'y_size': 124,
#    'type': 'Float32',
#    'nodata': 9.969209968386869e+36,
#    'statistics': [0.0,
#     63.86207962036133,
#     2.612993378999285,
#     2.9090176143585573]}}}

# %%
importlib.reload(rasterAPI)
info = rasterAPI.rasterInfo('/data/Hansen_GFC-2019-v1.7_last_20N_060W.tif', request_stats=True)
info
# Out:
# {'proj4': '+proj=longlat +datum=WGS84 +no_defs',
#  'x_ul': -60.0,
#  'x_res': 0.00025,
#  'x_skew': 0.0,
#  'y_ul': 20.0,
#  'y_skew': 0.0,
#  'y_res': -0.00025,
#  'geotransform': '-60.0, 0.00025, 0.0, 20.0, 0.0, -0.00025',
#  'count': 4,
#  'x_size': 40000,
#  'y_size': 40000,
#  'bands': {'1': {'x_size': 40000,
#    'y_size': 40000,
#    'type': 'Byte',
#    'nodata': None,
#    'statistics': [11.0, 67.0, 22.96969696969697, 9.40175627849892]},
#   '2': {'x_size': 40000,
#    'y_size': 40000,
#    'type': 'Byte',
#    'nodata': None,
#    'statistics': [2.0, 90.0, 13.87878787878788, 21.933449722115768]},
#   '3': {'x_size': 40000,
#    'y_size': 40000,
#    'type': 'Byte',
#    'nodata': None,
#    'statistics': [9.0, 106.0, 26.12121212121212, 19.728087308043637]},
#   '4': {'x_size': 40000,
#    'y_size': 40000,
#    'type': 'Byte',
#    'nodata': None,
#    'statistics': [0.0, 84.0, 0.10847620573626021, 1.7679680090610743]}}}

# %% [markdown]
# ### rasterIdentify

# %%
importlib.reload(rasterAPI)
res = rasterAPI.rasterIdentify('/data/CAMX_LAMMA_2019_NO2_IT_TUSCANY-MAP_FILE-20240731-ee2be3-1167.tiff', band=1, lon=10, lat=43)
res
# Out:
# {'value': 1.3495266437530518}

# %%
importlib.reload(rasterAPI)
res = rasterAPI.rasterIdentify('/data/Hansen_GFC-2019-v1.7_last_20N_060W.tif', band=3, lon=-59.57, lat=13.13)
res
# Out:
# {'value': 96.0}

# %% [markdown]
# ### rasterQuery: get raster values in a list of points

# %%
import numpy as np
lon = list(np.linspace(10.0, 12.0, 10))
lat = list(np.linspace(43.0, 44.0, 10))

importlib.reload(rasterAPI)
q = rasterAPI.rasterQuery('/data/CAMX_LAMMA_2019_NO2_IT_TUSCANY-MAP_FILE-20240731-ee2be3-1167.tiff', band=1, lon=lon, lat=lat)
q
# Out:
# {'values': [1.3495266437530518,
#   1.697713017463684,
#   2.27750301361084,
#   2.430579662322998,
#   2.4716060161590576,
#   4.811127662658691,
#   4.5345306396484375,
#   2.075084924697876,
#   1.3296974897384644,
#   1.6012464761734009]}
