# %% [markdown]
# ### redisStore

# %%
# %run redisAPI.py
code = redisStore('abcdefghijklm', expire=200)
code

# %% [markdown]
# ### redisGet

# %%
# %run redisAPI.py
res = redisGet('22aebdd14e')
res

# %% [markdown]
# ### redisDelete

# %%
# %run redisAPI.py
res = redisDelete('22aebdd14e')
res
