# %% [markdown]
# ### rasterInfo

# %%
# %run rasterAPI.py
info = rasterInfo('/data/CAMX_LAMMA_2019_NO2_IT_TUSCANY-MAP_FILE-20240731-ee2be3-1167.tiff', request_stats=True)
info

# %% [markdown]
# ### rasterIdentify

# %%
# %run rasterAPI.py
res = rasterIdentify('/data/CAMX_LAMMA_2019_NO2_IT_TUSCANY-MAP_FILE-20240731-ee2be3-1167.tiff', band=1, lon=10, lat=43)
res

# %% [markdown]
# ### rasterQuery: get raster values in a list of points

# %%
import numpy as np
lon = list(np.linspace(10.0, 12.0, 10))
lat = list(np.linspace(43.0, 44.0, 10))

# %run rasterAPI.py
q = rasterQuery('/data/CAMX_LAMMA_2019_NO2_IT_TUSCANY-MAP_FILE-20240731-ee2be3-1167.tiff', band=1, lon=lon, lat=lat)
q
